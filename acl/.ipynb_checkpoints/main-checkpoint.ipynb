# %%
import numpy as np
import torch
from matplotlib import pyplot as plt
# %matplotlib inline

from model import NN

from torch.optim.lr_scheduler import StepLR


#from train import training_routine_uniform
from functions import uniform_circle_loss_function_method2
from train import training_routine
from train import testing_routine

from visuals import plot_transformed_grid_and_density, compute_uniform_circle_density

from pathlib import Path

# %%
def save_model(model, data = 'Ellipse', checkpoint_number=1):
    checkpoints_dir= './checkpoints/'
    save_path = Path(checkpoints_dir) / Path("{}/experiment{}.pth".format(data, checkpoint_number))
    save_path.parent.mkdir(parents=True, exist_ok=True)
    torch.save(model.state_dict(), save_path)
    print("Saved checkpoint:", save_path)
    
def load_model(num_coupling_layers=3,layer_size=2, split_size_x1=1, nn_size=(1,100), path=f"./checkpoints/Ellipse/experiment{1}.pth"):
    model = NN(num_coupling_layers, layer_size, split_size_x1, nn_size).to(device)
    model.load_state_dict(torch.load(path))
    model.eval()
    return model

# %%
torch.set_default_dtype(torch.float64)
torch.manual_seed(2)
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
def generate_ellipse(max_num = 10000, scale=(0.5,0.2)):
    data = (torch.rand((max_num,2))-0.5)*2
    dist = torch.sum(torch.square(data),axis=1)
    data = data[torch.where(dist <= 1)]
    data *= torch.tensor(scale)
    return data

# %%
train_loader = generate_ellipse(max_num=100000, scale=(0.5,0.2))
test_loader = generate_ellipse(max_num=10000, scale=(0.5,0.2))
plt.scatter(np.array(train_loader)[:,0], np.array(train_loader)[:,1])

# %% [markdown]
# # Training with uniform density

# %%
torch.manual_seed(0)

model = NN(num_coupling_layers=3,layer_size=2, split_size_x1=1, nn_size=(1,100)).to(device)
model
# Out:
# NN(
#   (layers): ModuleList(
#     (0-2): 3 x CouplingLayer(
#       (t_net): ModuleList(
#         (0): Linear(in_features=1, out_features=100, bias=True)
#         (1): Linear(in_features=100, out_features=100, bias=True)
#         (2): Linear(in_features=100, out_features=1, bias=True)
#       )
#       (s_net): ModuleList(
#         (0): Linear(in_features=1, out_features=100, bias=True)
#         (1): Linear(in_features=100, out_features=100, bias=True)
#         (2): Linear(in_features=100, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.8)
scheduler = StepLR(optimizer, step_size=1, gamma=0.98)
num_epoch = 20

# %%
# %%time

batch_size = 1024 # Batch size must be very large! otherwise density gets concentrated if next data point is not in reach
for epoch in range(num_epoch):
    training_routine(model, device, train_loader, optimizer, epoch, batch_size, uniform_circle_loss_function_method2) 
    print(testing_routine(model, device, test_loader, batch_size, uniform_circle_loss_function_method2))
# Out:
# tensor(-2761.4468, device='cuda:0')
# tensor(-10442.8808, device='cuda:0')
# tensor(-16861.4170, device='cuda:0')
# tensor(-16919.9459, device='cuda:0')
# tensor(-16926.1474, device='cuda:0')
# tensor(-16928.9137, device='cuda:0')
# tensor(-16930.3072, device='cuda:0')
# tensor(-16931.0964, device='cuda:0')
# tensor(-16931.6058, device='cuda:0')
# tensor(-16931.9788, device='cuda:0')
# tensor(-16932.2764, device='cuda:0')
# tensor(-16932.5282, device='cuda:0')
# tensor(-16932.7460, device='cuda:0')
# tensor(-16932.9403, device='cuda:0')
# tensor(-16933.1138, device='cuda:0')
# tensor(-16933.2711, device='cuda:0')
# tensor(-16933.4152, device='cuda:0')
# tensor(-16933.5479, device='cuda:0')
# tensor(-16933.6700, device='cuda:0')
# tensor(-16933.7841, device='cuda:0')
# CPU times: total: 25.1 s
# Wall time: 25.5 s

# %%
scale=1
factor=1

sampling_data = generate_ellipse(1000, (1, 1))
plot_transformed_grid_and_density(model, train_loader, device, sampling_data, grid_width=30,
                                x_range=(-factor, factor), y_range=(-factor, factor), x_lim=(-0.5*scale,0.5*scale), y_lim=(-0.25*scale,0.25*scale),
                                density_function=compute_uniform_circle_density)
# Out:
# 0

# %%
def generate_banana(n=100000):
    train_loader = generate_ellipse(n)
    train_loader[:, 1] = train_loader[:,1] + 2*train_loader[:,0]**2
    return train_loader
train_loader = generate_banana()
test_loader = generate_banana(10000)
plt.scatter(np.array(train_loader)[:,0], np.array(train_loader)[:,1])

# %%
model_banana = NN(num_coupling_layers=8,layer_size=2, split_size_x1=1, nn_size=(1,200)).to(device)

# %%
optimizer = torch.optim.SGD(model_banana.parameters(), lr=0.1, momentum=0.8)
scheduler = StepLR(optimizer, step_size=1, gamma=0.98)
num_epoch = 20

# %%
# %%time

batch_size = 128 # Batch size must be very large! otherwise density gets concentrated if next data point is not in reach
for epoch in range(num_epoch):
    training_routine(model_banana, device, train_loader, optimizer, epoch, batch_size, uniform_circle_loss_function_method2) 
    print(testing_routine(model_banana, device, test_loader, batch_size, uniform_circle_loss_function_method2))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:21<00:00, 28.84it/s]
# tensor(-12812.5492, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:22<00:00, 26.94it/s]
# tensor(-17453.3541, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:26<00:00, 23.12it/s]
# tensor(-15934.1293, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:30<00:00, 20.08it/s]
# tensor(-14331.9188, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:41<00:00, 14.85it/s]
# tensor(-17119.7590, device='cuda:0')
#  14%|███████████▎                                                                     | 86/613 [00:06<00:41, 12.70it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:3
#
# File D:\master-thesis\acl\train.py:20, in training_routine(model, device, train_loader, optimizer, epoch, batch_size, loss_function)
#      17 for j in range(len(model.layers)):
#      18     layers.append("layers.{}".format(j))
# ---> 20 for k in tqdm(range(int(len(train_loader) / batch_size))):
#      21     saved_layers = register_activation_hooks(model, layers_to_save=layers)
#      22     inputs = train_loader[k * batch_size: k * batch_size + batch_size]
#
# File D:\master-thesis\venv\Lib\site-packages\tqdm\std.py:1192, in tqdm.__iter__(self)
#    1190 dt = cur_t - last_print_t
#    1191 if dt >= mininterval and cur_t >= min_start_t:
# -> 1192     self.update(n - last_print_n)
#    1193     last_print_n = self.last_print_n
#    1194     last_print_t = self.last_print_t
#
# File D:\master-thesis\venv\Lib\site-packages\tqdm\std.py:1243, in tqdm.update(self, n)
#    1241     self._ema_dn(dn)
#    1242     self._ema_dt(dt)
# -> 1243 self.refresh(lock_args=self.lock_args)
#    1244 if self.dynamic_miniters:
#    1245     # If no `miniters` was specified, adjust automatically to the
#    1246     # maximum iteration rate seen so far between two prints.
#    1247     # e.g.: After running `tqdm.update(5)`, subsequent
#    1248     # calls to `tqdm.update()` will only cause an update after
#    1249     # at least 5 more iterations.
#    1250     if self.maxinterval and dt >= self.maxinterval:
#
# File D:\master-thesis\venv\Lib\site-packages\tqdm\std.py:1348, in tqdm.refresh(self, nolock, lock_args)
#    1346     else:
#    1347         self._lock.acquire()
# -> 1348 self.display()
#    1349 if not nolock:
#    1350     self._lock.release()
#
# File D:\master-thesis\venv\Lib\site-packages\tqdm\std.py:1496, in tqdm.display(self, msg, pos)
#    1494 if pos:
#    1495     self.moveto(pos)
# -> 1496 self.sp(self.__str__() if msg is None else msg)
#    1497 if pos:
#    1498     self.moveto(-pos)
#
# File D:\master-thesis\venv\Lib\site-packages\tqdm\std.py:462, in tqdm.status_printer.<locals>.print_status(s)
#     460 def print_status(s):
#     461     len_s = disp_len(s)
# --> 462     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     463     last_len[0] = len_s
#
# File D:\master-thesis\venv\Lib\site-packages\tqdm\std.py:455, in tqdm.status_printer.<locals>.fp_write(s)
#     454 def fp_write(s):
# --> 455     fp.write(str(s))
#     456     fp_flush()
#
# File D:\master-thesis\venv\Lib\site-packages\tqdm\utils.py:195, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     193 def inner(*args, **kwargs):
#     194     try:
# --> 195         return func(*args, **kwargs)
#     196     except OSError as e:
#     197         if e.errno != 5:
#
# File D:\master-thesis\venv\Lib\site-packages\ipykernel\iostream.py:694, in OutStream.write(self, string)
#     692     self.pub_thread.schedule(self._flush)
#     693 else:
# --> 694     self._schedule_flush()
#     696 return len(string)
#
# File D:\master-thesis\venv\Lib\site-packages\ipykernel\iostream.py:590, in OutStream._schedule_flush(self)
#     587 def _schedule_in_thread():
#     588     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 590 self.pub_thread.schedule(_schedule_in_thread)
#
# File D:\master-thesis\venv\Lib\site-packages\ipykernel\iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File D:\master-thesis\venv\Lib\site-packages\zmq\sugar\socket.py:696, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     689         data = zmq.Frame(
#     690             data,
#     691             track=track,
#     692             copy=copy or None,
#     693             copy_threshold=self.copy_threshold,
#     694         )
#     695     data.group = group
# --> 696 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\\backend\\cython\\socket.pyx:742, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\\backend\\cython\\socket.pyx:789, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\\backend\\cython\\socket.pyx:250, in zmq.backend.cython.socket._send_copy()
#
# File D:\master-thesis\venv\Lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
scale=1
factor=1

sampling_data = generate_ellipse(1000, (1, 1))
plot_transformed_grid_and_density(model_banana, train_loader, device, sampling_data, grid_width=30,
                                x_range=(-factor, factor), y_range=(-factor, factor), x_lim=(-0.5*scale,0.5*scale), y_lim=(-0.2*scale,0.5*scale),
                                density_function=compute_uniform_circle_density)
# Out:
# D:\master-thesis\acl\visuals.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   output = model(torch.tensor(sampling_data, device=device), reverse=True)
# 0

# %%
scale=3
factor=2

sampling_data = generate_ellipse(1000, (1, 1))
plot_transformed_grid_and_density(model_banana, train_loader, device, sampling_data, grid_width=30,
                                x_range=(-factor, factor), y_range=(-factor, factor), x_lim=(-0.5*scale,0.5*scale), y_lim=(-0.2*scale,0.5*scale),
                                density_function=compute_uniform_circle_density)
# Out:
# 0

# %%
def generate_wave(n=100000):
    train_loader = generate_ellipse(n, (1,1))
    train_loader[:, 1] = train_loader[:,1] + 2*torch.sin(3*train_loader[:,0])
    return train_loader
train_loader = generate_wave()
test_loader = generate_wave(10000)
plt.scatter(np.array(train_loader)[:,0], np.array(train_loader)[:,1])

# %%
#model_wave=load_model(num_coupling_layers=8,layer_size=2, split_size_x1=1, nn_size=(1,200), path=f"./checkpoints/Wave/experiment{1}.pth")
model_wave=load_model(num_coupling_layers=8,layer_size=2, split_size_x1=1, nn_size=(1,200), path=f"./checkpoints/Wave/experiment{2}.pth")

# %%
model_wave = NN(num_coupling_layers=12,layer_size=2, split_size_x1=1, nn_size=(1,200)).to(device)

# %%
optimizer = torch.optim.SGD(model_wave.parameters(), lr=0.1, momentum=0.8)
scheduler = StepLR(optimizer, step_size=1, gamma=0.98)
num_epoch = 20

# %%
# %%time

batch_size = 128 # Batch size must be very large! otherwise density gets concentrated if next data point is not in reach
for epoch in range(num_epoch):
    training_routine(model_wave, device, train_loader, optimizer, epoch, batch_size, uniform_circle_loss_function_method2) 
    print(testing_routine(model_wave, device, test_loader, batch_size, uniform_circle_loss_function_method2))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:28<00:00, 21.20it/s]
# tensor(4632.8491, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:35<00:00, 17.41it/s]
# tensor(2496.2471, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:41<00:00, 14.73it/s]
# tensor(2424.8799, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [00:48<00:00, 12.55it/s]
# tensor(2328.4359, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [01:10<00:00,  8.68it/s]
# tensor(2197.3106, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [01:28<00:00,  6.89it/s]
# tensor(2399.3715, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [01:53<00:00,  5.41it/s]
# tensor(2575.0001, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [02:20<00:00,  4.38it/s]
# tensor(2392.4567, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [02:56<00:00,  3.47it/s]
# tensor(2554.3405, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [03:45<00:00,  2.72it/s]
# tensor(2301.8720, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [04:43<00:00,  2.16it/s]
# tensor(2347.8892, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [05:28<00:00,  1.87it/s]
# tensor(2315.3126, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [06:28<00:00,  1.58it/s]
# tensor(2114.3681, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [07:41<00:00,  1.33it/s]
# tensor(2550.0926, device='cuda:0')
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [06:45<00:00,  1.51it/s]
# tensor(2341.0389, device='cuda:0')
#  60%|████████████████████████████████████████████████                                | 368/613 [04:44<03:09,  1.29it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:3
#
# File D:\master-thesis\acl\train.py:25, in training_routine(model, device, train_loader, optimizer, epoch, batch_size, loss_function)
#      23 inputs = inputs.to(device)
#      24 optimizer.zero_grad(set_to_none=True)
# ---> 25 output = model(inputs)
#      26 loss = loss_function(output, saved_layers)
#      27 train_loss += loss
#
# File D:\master-thesis\venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File D:\master-thesis\venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File D:\master-thesis\acl\model.py:89, in NN.forward(self, x, reverse)
#      87 else:
#      88     for layer in self.layers:
# ---> 89         x, log_det = layer(x, reverse)
#      90 return x
#
# File D:\master-thesis\venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File D:\master-thesis\venv\Lib\site-packages\torch\nn\modules\module.py:1561, in Module._call_impl(self, *args, **kwargs)
#    1558     bw_hook = hooks.BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1559     args = bw_hook.setup_input_hook(args)
# -> 1561 result = forward_call(*args, **kwargs)
#    1562 if _global_forward_hooks or self._forward_hooks:
#    1563     for hook_id, hook in (
#    1564         *_global_forward_hooks.items(),
#    1565         *self._forward_hooks.items(),
#    1566     ):
#    1567         # mark that always called hook is run
#
# File D:\master-thesis\acl\model.py:35, in CouplingLayer.forward(self, x, reverse)
#      34 def forward(self, x, reverse=False):
# ---> 35     t = self.t_net[0](x[:, self.split_index[0]])
#      36     t = self.activation(t)
#      37     for i in range(1, len(self.t_net) - 1):
#
# File D:\master-thesis\venv\Lib\site-packages\torch\nn\modules\module.py:1507, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1504             tracing_state.pop_scope()
#    1505     return result
# -> 1507 def _wrapped_call_impl(self, *args, **kwargs):
#    1508     if self._compiled_call_impl is not None:
#    1509         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:

# %%
scale=1
factor=1

sampling_data = generate_ellipse(1000, (1, 1))
plot_transformed_grid_and_density(model_wave, train_loader, device, sampling_data, grid_width=30,
                                x_range=(-factor, factor), y_range=(-factor, factor), x_lim=(-1.2*scale,1.2*scale), y_lim=(-3*scale,3*scale),
                                density_function=compute_uniform_circle_density)
# Out:
# D:\master-thesis\acl\visuals.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   output = model(torch.tensor(sampling_data, device=device), reverse=True)
# 0

# %%
save_model(model_wave, data='Wave', checkpoint_number = 2)
# Out:
# Saved checkpoint: checkpoints\Wave\experiment2.pth

# %% [markdown]
# # Hyperparam Search

# %%
# hyperparameter tuning

from hyperopt import hp

space = {'num_couling_layers' : hp.randint('num_couling_layers', 5, 20), #so definiert man das interval (0, 2)      
        'learning_rate' : hp.uniform ('learning_rate', 0.1, 1),
         'momentum' : hp.uniform ('momentum', 0.1, 1.),
         'step_size': hp.choice('step_size', [1,2,3]),
         'gamma' : hp.uniform ('gamma', 0.8, 1),
         'num_epoch' : hp.randint('num_epoch', 3, 50),
         'batch_size_exponent' : hp.randint('batch_size_exponent', 10, 15),
         #'density_param_increment' : hp.uniform ('density_param_increment', 0.1, 1),
         'NN_depth' : hp.choice('NN_depth', [1,2,3,4,5]),   #so kann man über Listen 
         'NN_width' : hp.randint('NN_width', 5, 200),
        }                                                                             #Hyperparamter suchen
#index spaces auch möglich
    # NUM_COUPLING_LAYERS = 10
    # NN_WIDTH = 0
    
    # LEARNING_RATE = 1
    # MOMENTUM = 0.8
    # STEP_SIZE = 1
    # GAMMA = 0.98

    # NUM_EPOCH = 20
    # BATCH_SIZE = 2**space['batch_size_exponent']

# 'batch_size_exponent': [7],
#     'density_param_increment': [0.44412861981816865],
#     'gamma': [0.8180486265222036],
#     'learning_rate': [0.9909497228897849],
#     'momentum': [0.7643280591564052],
#     'num_couling_layers': [10],
#     'num_epoch': [11],
#     'step_size': [1]


# space = {'num_couling_layers' : hp.randint('num_couling_layers', 10, 11), #so definiert man das interval (0, 2)      
#         'learning_rate' : hp.uniform ('learning_rate', 0.9, 1),
#          'momentum' : hp.uniform ('momentum', 0.7, 0.8),
#          'step_size': hp.choice('step_size', [1,2]),
#          'gamma' : hp.uniform ('gamma', 0.8, 1),
#          'num_epoch' : hp.randint('num_epoch', 10, 12),
#          'batch_size_exponent' : hp.randint('batch_size_exponent', 7, 8),
#          'density_param_increment' : hp.uniform ('density_param_increment', 1, 1)
#         #'NN_size' : hp.choice('NN_size', [[16,16],[32,32],[64],[128],[256],[512]]),   #so kann man über Listen 
#         }

# %%
from torch.optim.lr_scheduler import StepLR

from train import training_routine_uniform
from functions import uniform_circle_loss_function

def objective(space):
    """
    Hier die Funktion einfügen, wo die Hyperparamter optimiert werden sollen
    
    Input: space, type: dictionary mit den Hyperparametern
    Output: Der Score/ die Accuracy
    """
    
    #collect all parameters
    NUM_COUPLING_LAYERS = space['num_couling_layers']
    
    LEARNING_RATE = space['learning_rate']
    MOMENTUM = space['momentum']
    STEP_SIZE = space['step_size']
    GAMMA = space['gamma']

    NUM_EPOCH = space['num_epoch']
    BATCH_SIZE = 2**space['batch_size_exponent']

    NN_SIZE = (space['NN_depth'], space['NN_width'])
    
    #DENSITY_PARAM_INCREMENT = space['density_param_increment']

    print(space['batch_size_exponent'])
    

    #make calculations
    
    torch.manual_seed(0)
    model = NN(num_coupling_layers=NUM_COUPLING_LAYERS,layer_size=2, split_size_x1=1, nn_size=NN_SIZE).to(device)

    optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
    scheduler = StepLR(optimizer, step_size=STEP_SIZE, gamma=GAMMA)
        
    num_epoch = NUM_EPOCH
    batch_size = BATCH_SIZE
    for epoch in range(num_epoch):
        #density_param = (1+DENSITY_PARAM_INCREMENT*epoch, 0.2)
        density_param = (1+10*(epoch+1)/num_epoch, 0.2)
        #print(density_param, epoch, num_epoch)
        training_routine_uniform(model, device, train_loader, optimizer, epoch, batch_size, uniform_circle_loss_function, density_param) 

    
    density_param = (11.,0.2)
    test_score = testing_routine_uniform(model, device, test_loader, batch_size, uniform_circle_loss_function, density_param)
    
    # We aim to maximize accuracy, therefore we return it as a negative value
    # Wenn also etwas maximiert werden soll, schreibe ein - im loss. Sonst lasse das minus weg
    # Man kann sich hier zusätzlich in der action_info Sachen merken.
    return {'loss': test_score, 'status': STATUS_OK}

# %%
def objective_method2(space):
    """
    Hier die Funktion einfügen, wo die Hyperparamter optimiert werden sollen
    
    Input: space, type: dictionary mit den Hyperparametern
    Output: Der Score/ die Accuracy
    """
    
    #collect all parameters
    NUM_COUPLING_LAYERS = space['num_couling_layers']
    
    LEARNING_RATE = space['learning_rate']
    MOMENTUM = space['momentum']
    STEP_SIZE = space['step_size']
    GAMMA = space['gamma']

    NUM_EPOCH = space['num_epoch']
    BATCH_SIZE = 2**space['batch_size_exponent']

    NN_SIZE = (space['NN_depth'], space['NN_width'])

    print(space['batch_size_exponent'])
    
    #make calculations
    
    torch.manual_seed(0)
    model = NN(num_coupling_layers=NUM_COUPLING_LAYERS,layer_size=2, split_size_x1=1, nn_size=NN_SIZE).to(device)

    optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
    scheduler = StepLR(optimizer, step_size=STEP_SIZE, gamma=GAMMA)
        
    num_epoch = NUM_EPOCH
    batch_size = BATCH_SIZE
    for epoch in range(num_epoch):
        training_routine(model, device, train_loader, optimizer, epoch, batch_size, uniform_circle_loss_function_method2) 

    test_score = testing_routine(model, device, test_loader, batch_size, uniform_circle_loss_function_method2)

    #
    # accuracy = test_score #calculate some kind of score/ accuracy 

    # #normalisiere am besten die Accuracy! (so dass es im (0,1) intervall ist)
    # accuracy = accuracy
    
    # We aim to maximize accuracy, therefore we return it as a negative value
    # Wenn also etwas maximiert werden soll, schreibe ein - im loss. Sonst lasse das minus weg
    # Man kann sich hier zusätzlich in der action_info Sachen merken.
    return {'loss': test_score, 'status': STATUS_OK}

# %%
import pickle
import os 
file_name = "acl2.hyperopt"

def run_trials(trials_step=1):
    #functions that runs the trials
    
    trials_step = trials_step  # how many additional trials to do after loading saved trials. 1 = save after iteration
    max_trials = 3  # initial max_trials. put something small to not have to wait
    
    try:  # try to load already saved trials
        trials = pickle.load(open(file_name, "rb"))
        print("Found saved Trials! Loading...")
        
        max_trials = len(trials.trials) + trials_step   #increase amount of maximal trials
        print("Rerunning from {} trials to {} (+{}) trials".format(len(trials.trials), max_trials, trials_step))
    except:  # create a new trials object and start searching
        print("Creating new Trial")
        trials = Trials()

    best = fmin(fn = objective_method2,   #function über die optimiert wird
            space = space,        #hyperparameter space
            algo = tpe.suggest,   #Algorithmus für Hyperparameter Suche
            max_evals = max_trials,  #wie viel trainieren
            trials = trials)        #nutze alte trials

    print("Run:", best)    #die besten hyperparameter werden hier geprinted

    #print(trials.trials)
    with open(file_name, "wb") as f:
        pickle.dump(trials, f)

# %%
# %%time
#hier können wir jetzt die trials laufen lassen
for k in range(1):
    run_trials(10)
# Out:
# Found saved Trials! Loading...
# Rerunning from 3 trials to 13 (+10) trials
# 11
# 13
# 14
# 11
# 11
# 10
# 11
# 12
# 12
# 14
# 100%|█████████████████████████████████████████████████████| 13/13 [06:03<00:00, 36.32s/trial, best loss: -16827.203125]
# Run: {'NN_depth': 1, 'NN_width': 69, 'batch_size_exponent': 10, 'gamma': 0.872909742777875, 'learning_rate': 0.1443378257116975, 'momentum': 0.9340286470573611, 'num_couling_layers': 15, 'num_epoch': 13, 'step_size': 2}
# CPU times: total: 5min 58s
# Wall time: 6min 3s

# %%
trials = pickle.load(open(file_name, "rb"))
# results = [(t['result']['loss'], t['misc']['vals']['learning_rate'], t['misc']['vals']['noise_std']) for t in trials.trials]
# df = pd.DataFrame(results, columns=['loss', 'lr', 'noise_std'])
# #df.iloc[np.argmin(df['loss'])]
# df
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': -16827.203125, 'status': 'ok'},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [0],
#     'NN_width': [0],
#     'batch_size_exponent': [0],
#     'gamma': [0],
#     'learning_rate': [0],
#     'momentum': [0],
#     'num_couling_layers': [0],
#     'num_epoch': [0],
#     'step_size': [0]},
#    'vals': {'NN_depth': [1],
#     'NN_width': [69],
#     'batch_size_exponent': [10],
#     'gamma': [0.872909742777875],
#     'learning_rate': [0.1443378257116975],
#     'momentum': [0.9340286470573611],
#     'num_couling_layers': [15],
#     'num_epoch': [13],
#     'step_size': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 1, 35, 292000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 2, 33, 310000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': 0.0, 'status': 'ok'},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [1],
#     'NN_width': [1],
#     'batch_size_exponent': [1],
#     'gamma': [1],
#     'learning_rate': [1],
#     'momentum': [1],
#     'num_couling_layers': [1],
#     'num_epoch': [1],
#     'step_size': [1]},
#    'vals': {'NN_depth': [1],
#     'NN_width': [122],
#     'batch_size_exponent': [14],
#     'gamma': [0.9977893572940995],
#     'learning_rate': [0.11118618488230751],
#     'momentum': [0.8984418675949839],
#     'num_couling_layers': [14],
#     'num_epoch': [11],
#     'step_size': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 2, 33, 313000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 2, 36, 445000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': nan, 'status': 'ok'},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [2],
#     'NN_width': [2],
#     'batch_size_exponent': [2],
#     'gamma': [2],
#     'learning_rate': [2],
#     'momentum': [2],
#     'num_couling_layers': [2],
#     'num_epoch': [2],
#     'step_size': [2]},
#    'vals': {'NN_depth': [0],
#     'NN_width': [158],
#     'batch_size_exponent': [10],
#     'gamma': [0.9705117233117897],
#     'learning_rate': [0.7807514037041683],
#     'momentum': [0.44294016757177],
#     'num_couling_layers': [8],
#     'num_epoch': [31],
#     'step_size': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 2, 36, 448000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 3, 55, 475000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': -13927.2724609375, 'status': 'ok'},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [3],
#     'NN_width': [3],
#     'batch_size_exponent': [3],
#     'gamma': [3],
#     'learning_rate': [3],
#     'momentum': [3],
#     'num_couling_layers': [3],
#     'num_epoch': [3],
#     'step_size': [3]},
#    'vals': {'NN_depth': [4],
#     'NN_width': [6],
#     'batch_size_exponent': [11],
#     'gamma': [0.9055292658962864],
#     'learning_rate': [0.43337096509919637],
#     'momentum': [0.38416401998450744],
#     'num_couling_layers': [6],
#     'num_epoch': [37],
#     'step_size': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 5, 25, 440000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 6, 10)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': 0.0, 'status': 'ok'},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [4],
#     'NN_width': [4],
#     'batch_size_exponent': [4],
#     'gamma': [4],
#     'learning_rate': [4],
#     'momentum': [4],
#     'num_couling_layers': [4],
#     'num_epoch': [4],
#     'step_size': [4]},
#    'vals': {'NN_depth': [3],
#     'NN_width': [56],
#     'batch_size_exponent': [13],
#     'gamma': [0.9547038621930174],
#     'learning_rate': [0.6723534672506553],
#     'momentum': [0.7116358184009479],
#     'num_couling_layers': [9],
#     'num_epoch': [32],
#     'step_size': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 6, 10, 3000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 6, 22, 675000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': 0.0, 'status': 'ok'},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [5],
#     'NN_width': [5],
#     'batch_size_exponent': [5],
#     'gamma': [5],
#     'learning_rate': [5],
#     'momentum': [5],
#     'num_couling_layers': [5],
#     'num_epoch': [5],
#     'step_size': [5]},
#    'vals': {'NN_depth': [3],
#     'NN_width': [86],
#     'batch_size_exponent': [14],
#     'gamma': [0.9015046028138591],
#     'learning_rate': [0.3306868323213904],
#     'momentum': [0.24103779192179214],
#     'num_couling_layers': [5],
#     'num_epoch': [37],
#     'step_size': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 6, 22, 678000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 6, 26, 997000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': -13932.087890625, 'status': 'ok'},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [6],
#     'NN_width': [6],
#     'batch_size_exponent': [6],
#     'gamma': [6],
#     'learning_rate': [6],
#     'momentum': [6],
#     'num_couling_layers': [6],
#     'num_epoch': [6],
#     'step_size': [6]},
#    'vals': {'NN_depth': [2],
#     'NN_width': [96],
#     'batch_size_exponent': [11],
#     'gamma': [0.8438677810997087],
#     'learning_rate': [0.6952617638509349],
#     'momentum': [0.12768863162647326],
#     'num_couling_layers': [15],
#     'num_epoch': [39],
#     'step_size': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 6, 26, 999000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 8, 7, 399000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': nan, 'status': 'ok'},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [7],
#     'NN_width': [7],
#     'batch_size_exponent': [7],
#     'gamma': [7],
#     'learning_rate': [7],
#     'momentum': [7],
#     'num_couling_layers': [7],
#     'num_epoch': [7],
#     'step_size': [7]},
#    'vals': {'NN_depth': [0],
#     'NN_width': [79],
#     'batch_size_exponent': [11],
#     'gamma': [0.9087613114569528],
#     'learning_rate': [0.928604167048794],
#     'momentum': [0.6965205310562526],
#     'num_couling_layers': [16],
#     'num_epoch': [21],
#     'step_size': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 8, 7, 402000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 8, 50, 484000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': -15562.3359375, 'status': 'ok'},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [8],
#     'NN_width': [8],
#     'batch_size_exponent': [8],
#     'gamma': [8],
#     'learning_rate': [8],
#     'momentum': [8],
#     'num_couling_layers': [8],
#     'num_epoch': [8],
#     'step_size': [8]},
#    'vals': {'NN_depth': [2],
#     'NN_width': [91],
#     'batch_size_exponent': [10],
#     'gamma': [0.9950389431494362],
#     'learning_rate': [0.6419378720874404],
#     'momentum': [0.8269597394427683],
#     'num_couling_layers': [6],
#     'num_epoch': [35],
#     'step_size': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 8, 50, 487000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 10, 13, 236000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': -12078.962890625, 'status': 'ok'},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [9],
#     'NN_width': [9],
#     'batch_size_exponent': [9],
#     'gamma': [9],
#     'learning_rate': [9],
#     'momentum': [9],
#     'num_couling_layers': [9],
#     'num_epoch': [9],
#     'step_size': [9]},
#    'vals': {'NN_depth': [0],
#     'NN_width': [7],
#     'batch_size_exponent': [11],
#     'gamma': [0.8626806216690031],
#     'learning_rate': [0.4364130067377171],
#     'momentum': [0.6615832516948797],
#     'num_couling_layers': [5],
#     'num_epoch': [14],
#     'step_size': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 10, 13, 239000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 10, 22, 228000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': -9446.099609375, 'status': 'ok'},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [10],
#     'NN_width': [10],
#     'batch_size_exponent': [10],
#     'gamma': [10],
#     'learning_rate': [10],
#     'momentum': [10],
#     'num_couling_layers': [10],
#     'num_epoch': [10],
#     'step_size': [10]},
#    'vals': {'NN_depth': [4],
#     'NN_width': [180],
#     'batch_size_exponent': [12],
#     'gamma': [0.8277611236069891],
#     'learning_rate': [0.975224988352034],
#     'momentum': [0.5572980772788059],
#     'num_couling_layers': [9],
#     'num_epoch': [26],
#     'step_size': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 10, 22, 231000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 10, 46, 875000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': -9383.7666015625, 'status': 'ok'},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [11],
#     'NN_width': [11],
#     'batch_size_exponent': [11],
#     'gamma': [11],
#     'learning_rate': [11],
#     'momentum': [11],
#     'num_couling_layers': [11],
#     'num_epoch': [11],
#     'step_size': [11]},
#    'vals': {'NN_depth': [0],
#     'NN_width': [151],
#     'batch_size_exponent': [12],
#     'gamma': [0.8276538130691238],
#     'learning_rate': [0.6098429177249279],
#     'momentum': [0.8808915379660229],
#     'num_couling_layers': [14],
#     'num_epoch': [29],
#     'step_size': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 10, 46, 878000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 11, 12, 956000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': 0.0, 'status': 'ok'},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'NN_depth': [12],
#     'NN_width': [12],
#     'batch_size_exponent': [12],
#     'gamma': [12],
#     'learning_rate': [12],
#     'momentum': [12],
#     'num_couling_layers': [12],
#     'num_epoch': [12],
#     'step_size': [12]},
#    'vals': {'NN_depth': [2],
#     'NN_width': [193],
#     'batch_size_exponent': [14],
#     'gamma': [0.9647574062737763],
#     'learning_rate': [0.2794018002698734],
#     'momentum': [0.9708011870667983],
#     'num_couling_layers': [10],
#     'num_epoch': [39],
#     'step_size': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 3, 12, 13, 11, 12, 958000),
#   'refresh_time': datetime.datetime(2024, 3, 12, 13, 11, 28, 669000)}]

# %%
# MISTAKE 2024-03-05: CHOOSE RIGHT LOSS_FUNCTION FOR TESTING. OTHERWISE NaN and inf VALUES BECOME COMMON!

# Todo: True loss function (Done)
# NN structure to params (Done)

# ACL and LU-Net hyperparam search 
# grid distortion term + hyperparam search 
 
# More complicated shapes
# 3D shapes

# Video by parameter interpolation

# %%
from visuals import plot_generating_uniform_density, compute_uniform_circle_density

# %%
sampling_data = generate_ellipse(1000, (1, 1))

range_param = 1.5

density_param = (100,0.02)

plot_generating_uniform_density(testNN, device, density_param, train_loader, sampling_data, grid_width=30,
                                x_range=(-range_param, range_param), y_range=(-range_param, range_param), x_lim=(-0.5,0.5), y_lim=(-0.25,0.25),
                                density_function=compute_uniform_circle_density)
# Out:
# tensor([inf, inf, inf,  ..., inf, inf, inf], device='cuda:0') tensor([inf, inf, inf,  ..., inf, inf, inf], device='cuda:0') tensor([2.3744, 2.3682, 2.3646,  ..., 2.3352, 2.3344, 2.3336], device='cuda:0')
# D:\master-thesis\acl\visuals.py:130: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   output = model(torch.tensor(sampling_data, dtype=torch.float32).to(device), reverse=True)
# 0

# %% [markdown]
# # Training with Gaussian Density

# %%
torch.manual_seed(0)

testNN = NN(num_coupling_layers=30,layer_size=2, split_size_x1=1, nn_size=(1,100)).to(device)
testNN
# Out:
# NN(
#   (layers): ModuleList(
#     (0-29): 30 x CouplingLayer(
#       (t_net): ModuleList(
#         (0): Linear(in_features=1, out_features=100, bias=True)
#         (1): Linear(in_features=100, out_features=100, bias=True)
#         (2): Linear(in_features=100, out_features=1, bias=True)
#       )
#       (s_net): ModuleList(
#         (0): Linear(in_features=1, out_features=100, bias=True)
#         (1): Linear(in_features=100, out_features=100, bias=True)
#         (2): Linear(in_features=100, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )

# %%
from torch.optim.lr_scheduler import StepLR

optimizer = torch.optim.SGD(testNN.parameters(), lr=1, momentum=0.8)
scheduler = StepLR(optimizer, step_size=1, gamma=0.98)

# %%
from train import training_routine
from functions import gaussian_loss_function

# %%
# %%time

num_epoch = 20
batch_size = 1024
for epoch in range(num_epoch):
    training_routine(testNN, device, train_loader, optimizer, epoch, batch_size, gaussian_loss_function)
# Out:
# CPU times: total: 3min 4s
# Wall time: 3min 5s

# %%
from visuals import plot_generating_gaussian_density, compute_gaussian_density

# %%
sampling_data = torch.normal(torch.zeros(1000,2), torch.ones(1000,2))
sampling_data
# Out:
# tensor([[-0.3505,  0.4639],
#         [ 0.1060,  0.6005],
#         [ 0.1557, -0.8488],
#         ...,
#         [-0.9496,  1.7330],
#         [-1.2764,  0.4050],
#         [ 0.3496, -0.0547]])

# %%
plot_generating_gaussian_density(testNN, device, density_param, train_loader, sampling_data.detach(), grid_width=30,
                                x_range=(-3, 3), y_range=(-3, 3), x_lim=(-0.5,0.5), y_lim=(-0.25,0.25))
# Out:
# torch.Size([1800]) torch.Size([1800, 10])
# tensor([3.3113, 2.7487, 2.2337,  ..., 3.5337, 3.9046, 4.3247], device='cuda:0') tensor(1.1447, dtype=torch.float64) tensor([9.0000, 8.4007, 7.8442,  ..., 7.8442, 8.4007, 9.0000], device='cuda:0') tensor([6.8334, 6.7967, 6.7552,  ..., 5.4552, 5.6408, 5.8201], device='cuda:0')
# 0
