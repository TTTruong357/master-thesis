# %%
import torch
from model import LUNet
from matplotlib import pyplot as plt
import numpy as np

from torch.optim.lr_scheduler import StepLR
from train import training_routine_gaussian, training_routine_uniform
from functions import uniform_circle_log_likelihood

from pathlib import Path

from model_inverted import InvertedLUNet
from visuals import plot_generating_uniform_density, compute_uniform_circle_density

# %%
def generate_ellipse(max_num = 10000, scale=(0.5,0.2)):
    data = (torch.rand((max_num,2))-0.5)*2
    dist = torch.sum(torch.square(data),axis=1)
    data = data[torch.where(dist <= 1)]
    data *= torch.tensor(scale)
    return data

train_loader = generate_ellipse()
test_loader = generate_ellipse(2000)
plt.scatter(np.array(train_loader)[:,0], np.array(train_loader)[:,1])

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
model = LUNet(num_lu_blocks=12, layer_size = 2).to(device)
# Out:
# ... initialized LUNet

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = StepLR(optimizer, step_size=1, gamma=0.95)
num_epochs = 50
#init_loss_dict(num_epochs) # number of epochs

# %%
# %%time
batch_size = 128
density_param=(5,0.2)

for epoch in range(1, num_epochs + 1):
    density_param = (1+epoch/4, 0.2)
    print("\nEpoch {}:".format(epoch))
    training_routine_uniform(model, device, train_loader, optimizer, epoch, batch_size, loss_function=uniform_circle_log_likelihood,density_param=density_param)
    #testing_routine_gaussian(model, device, test_loader, batch_size,loss_function=uniform_circle_log_likelihood,density_param=density_param, plot_name="epoch_{:03d}.png".format(epoch))
    #save_model_for_animation(model=model, epoch=epoch)
    scheduler.step()
# Out:
# Epoch 1:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:03<00:00, 19.43it/s]
# Epoch 2:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:01<00:00, 46.05it/s]
# Epoch 3:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:01<00:00, 44.67it/s]
# Epoch 4:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:01<00:00, 38.13it/s]
# Epoch 5:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:01<00:00, 39.27it/s]
# Epoch 6:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:01<00:00, 39.95it/s]
# Epoch 7:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:01<00:00, 38.94it/s]
# Epoch 8:
# ...

# %%
save_model = True
checkpoints_dir= './checkpoints/'
data = 'Ellipse'
checkpoint_number =  7
num_lu_blocks = 12
layer_size = 2

if save_model:
    save_path = Path(checkpoints_dir) / Path("{}/experiment{}.pth".format(data, checkpoint_number))
    save_path.parent.mkdir(parents=True, exist_ok=True)
    torch.save(model.state_dict(), save_path)
    print("Saved checkpoint:", save_path)
# Out:
# Saved checkpoint: checkpoints\Ellipse\experiment7.pth

# %%
# checkpoint_number =  4
# num_lu_blocks = 12
# layer_size = 2
# density_param = (1+30/4, 0.2)

def load_model(num_lu_blocks=12, layer_size = 2, path=f"./checkpoints/Ellipse/experiment{checkpoint_number}.pth"):
    model = LUNet(num_lu_blocks=num_lu_blocks, layer_size = layer_size).to(device)
    model.load_state_dict(torch.load(path))
    model.eval()
    return model

# %%
model = load_model(num_lu_blocks, layer_size, f"./checkpoints/Ellipse/experiment{checkpoint_number}.pth")
# Out:
# ... initialized LUNet

# %%
inverted_model = InvertedLUNet(num_lu_blocks,save_path=f"./checkpoints/Ellipse/experiment{checkpoint_number}.pth")
# Out:
# ... initialized inverted LUNet

# %%
sampling_data = generate_ellipse(1000, (1, 1))

# %%
plot_generating_uniform_density(model, inverted_model, device, density_param, train_loader, sampling_data, grid_width=30,
                                x_range=(-1.35, 1.35), y_range=(-1.35, 1.35), x_lim=(-0.5,0.5), y_lim=(-0.25,0.25),
                                density_function=compute_uniform_circle_density)
# Out:
# 0

# %%
inverted_model(torch.tensor([[0,0.]]))
# Out:
# tensor([[-0.0357, -0.0105]], device='cuda:0')
